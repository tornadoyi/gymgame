# %%
import sword
sword.run(True)
# Out:
# [2017-08-14 16:32:26,846] Making new env: tiny-rpg-sword-v0
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c7c71620-3744-4fd9-9553-2ad0923daf6f">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-45417d10c520> in <module>()
#       1 import sword
# ----> 2 sword.run(True)
#
# ~/Projects/gymgame/test/sword/sword.py in run(render)
#      18         time.sleep(1.0/600)
#      19         env.step([0, env.game.map.npcs[0]])
# ---> 20         if render: env.render()
#      21
#      22
#
# ~/Projects/gymgame/gymgame/framework/env.py in render(self, mode, close)
#     107     def close(self): gym.Env.close(self)
#     108
# --> 109     def render(self, mode='human', close=False): gym.Env.render(self, mode, close)
# ...
