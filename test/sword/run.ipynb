# %%
import sword
sword.run(True)
# Out:
# [2017-06-30 21:28:28,783] Making new env: tiny-rpg-sword-v0
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5ab337fa-6fe7-4d47-80d2-e15b9d4b7cb8">Loading BokehJS ...</span>
#     </div>
# /Applications/anaconda/envs/python35/lib/python3.5/site-packages/bokeh/io.py:508: UserWarning: Cannot find a last shown plot to update. Call output_notebook() and show(..., notebook_handle=True) before push_notebook()
#   warnings.warn("Cannot find a last shown plot to update. Call output_notebook() and show(..., notebook_handle=True) before push_notebook()")
